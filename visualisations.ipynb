# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
p_df = pd.read_csv("https://raw.githubusercontent.com/stho382/ENGSCI_263_group_3_CM/main/data/gr_p.txt?token=APIMSVRGINTROPGUWYO7IJTBBGZMO")
q1_df = pd.read_csv("https://raw.githubusercontent.com/stho382/ENGSCI_263_group_3_CM/main/data/gr_q1.txt?token=APIMSVSEKVUYUKOZFWOJOULBBGZPI") 
q2_df = pd.read_csv("https://raw.githubusercontent.com/stho382/ENGSCI_263_group_3_CM/main/data/gr_q2.txt?token=APIMSVQ4433NUDJEKCG4N6TBBGZRG")
T_df = pd.read_csv("https://raw.githubusercontent.com/stho382/ENGSCI_263_group_3_CM/main/data/gr_T.txt?token=APIMSVQGLYYQQHWWX3XNTC3BBGZTE")

# %%
p_df.head()
# Out:
#       year  water level (m)
# 0  1984.75          294.787
# 1  1985.11          295.009
# 2  1985.72          294.362
# 3  1986.20          294.805
# 4  1986.59          294.222

# %%
q1_df.head()
# Out:
#       year  production rate (tonnes/day)
# 0  1950.51                       66.5399
# 1  1951.73                      199.6200
# 2  1952.94                      465.7790
# 3  1953.90                      731.9390
# 4  1955.30                      998.0990

# %%
q2_df.head()
# Out:
#       year  production rate (tonnes/day)
# 0  1950.32                       132.500
# 1  1954.16                       527.054
# 2  1955.51                       658.507
# 3  1958.45                      1386.040
# 4  1961.46                      1515.800

# %%
T_df.head()
# Out:
#    year   temperature [degC]
# 0  1960                149.0
# 1  1965                145.0
# 2  1970                147.0
# 3  1975                144.0
# 4  1980                141.0

# %%
plt.scatter(p_df["year"], p_df["water level (m)"])
plt.title("Water level data from Rotorua Geothermal System")
# Out:
# Text(0.5, 1.0, 'Water level data from Rotorua Geothermal System')

# %%
plt.scatter(q1_df["year"], q1_df["production rate (tonnes/day)"])

# %%
plt.scatter(q2_df["year"], q2_df["production rate (tonnes/day)"])

# %%
plt.scatter(T_df["year"], T_df.iloc[:,1])
plt.title("Temperature Monitoring data from near Whakarewarewa")
# Out:
# Text(0.5, 1.0, 'Temperature Monitoring data from near Whakarewarewa')
